# %%
from PIL import Image
import cv2
import numpy as np
from matplotlib import pyplot as plt
from skimage.morphology import skeletonize
from skimage.util import invert
from skimage import morphology, filters
from skimage import io
import os.path
from os import path
from tensorflow import keras
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import time
from datetime import timedelta
import convolutional
# Out:
# WARNING:tensorflow:From C:\Users\hungm\anaconda3\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
def processing_image(directory):
    img = cv2.imread(directory)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    m,n =  img.shape

    img_new = np.zeros([m, n]) 

    for i in range(1, m-1): 
        for j in range(1, n-1): 
            temp = [img[i-1, j-1], 
                img[i-1, j], 
                img[i-1, j + 1], 
                img[i, j-1], 
                img[i, j], 
                img[i, j + 1], 
                img[i + 1, j-1], 
                img[i + 1, j], 
                img[i + 1, j + 1]] 
            
            temp = sorted(temp) 
            img_new[i, j]= temp[4] 
    
    img_new = img_new.astype(np.uint8) 
    img_new = cv2.equalizeHist(img_new)

    image = invert(img_new,0)

    img = image.copy()
    skel = img.copy()
    skel[:,:] = 0
    kernel = cv2.getStructuringElement(cv2.MORPH_CROSS, (5,5))
    iterations = 0

    while True:
        eroded = cv2.morphologyEx(img, cv2.MORPH_ERODE, kernel)
        temp = cv2.morphologyEx(eroded, cv2.MORPH_DILATE, kernel)
        temp  = cv2.subtract(img, temp)
        skel = cv2.bitwise_or(skel, temp)
        img[:,:] = eroded[:,:]
        if cv2.countNonZero(img) == 0:
            break
    ret, thr = cv2.threshold(skel, 5,255, cv2.THRESH_BINARY)
    #thr = cv2.resize(thr,(64,48))
    
    #cv2.imshow(directory,thr) 
    #cv2.waitKey(0)
    #thr = thr.reshape(1,48*64)
    return thr
def SaveImage():
    for i in range(1, 313):
        subject = str(i).zfill(4)
        parent_dir = 'D:\\palmvein\\'
        dic = os.path.join(parent_dir, subject)
        if path.exists(dic):
            pass
        else:
            os.mkdir(dic)
        dic_ml = 'D:\\dataset\\' + subject + '\\' + subject + '_' + 'm' + '_' + 'l' + '_' + '01' + '.jpg'
        dic_mr = 'D:\\dataset\\' + subject + '\\' + subject + '_' + 'm' + '_' + 'r' + '_' + '01' + '.jpg'
        dic_fl = 'D:\\dataset\\' + subject + '\\' + subject + '_' + 'f' + '_' + 'l' + '_' + '01' + '.jpg'
        dic_fr = 'D:\\dataset\\' + subject + '\\' + subject + '_' + 'f' + '_' + 'r' + '_' + '01' + '.jpg'
        save_ml = 'D:\\palmvein\\' + subject + '\\' + subject + '_' + 'm' + '_' + 'l' + '_' + '01' + '.jpg'
        save_mr = 'D:\\palmvein\\' + subject + '\\' + subject + '_' + 'm' + '_' + 'r' + '_' + '01' + '.jpg'
        save_fl = 'D:\\palmvein\\' + subject + '\\' + subject + '_' + 'f' + '_' + 'l' + '_' + '01' + '.jpg'
        save_fr = 'D:\\palmvein\\' + subject + '\\' + subject + '_' + 'f' + '_' + 'r' + '_' + '01' + '.jpg'
        if path.exists(dic_fr) == False and path.exists(dic_fl) == False and path.exists(dic_mr) == False and path.exists(dic_ml) == False :
            continue
        if path.exists(dic_ml) == True:
            for j in range(1, 9):
                dic_ml = dic_ml[:26] + str(j) + '.jpg'
                save_ml = save_ml[:27] + str(j) +'.jpg'
                if path.exists(dic_ml) == False:
                    continue
                img = processing_image(dic_ml)
                x = Image.fromarray(img)
                x.save(save_ml)
        if path.exists(dic_mr) == True:
            for j in range(1, 9):
                dic_mr = dic_mr[:26] + str(j) + '.jpg'
                save_mr = save_mr[:27] + str(j) +'.jpg'
                if path.exists(dic_mr) == False:
                    continue
                img = processing_image(dic_mr)
                x = Image.fromarray(img)
                x.save(save_mr)
        if path.exists(dic_fl) == True:
            for j in range(1, 9):
                dic_fl = dic_fl[:26] + str(j) + '.jpg'
                save_fl = save_fl[:27] + str(j) +'.jpg'
                if path.exists(dic_fl) == False:
                    continue
                img = processing_image(dic_fl)
                x = Image.fromarray(img)
                x.save(save_fl)
        if path.exists(dic_fr) == True:
            for j in range(1, 9):
                dic_fr = dic_fr[:26] + str(j) + '.jpg'
                save_fr = save_fr[:27] + str(j) +'.jpg'
                if path.exists(dic_fr) == False:
                    continue
                img = processing_image(dic_fr)
                x = Image.fromarray(img)
                x.save(save_fr)
        
    return True

# %%
def convertImagetoArray(image):
    img = cv2.imread(image,cv2.IMREAD_GRAYSCALE)
    thr = cv2.resize(img,(64,48))
    thr = thr.reshape(1,48*64)
    return thr

# %%
def extractdatabase(LeftOrRight,numberofseries):
    trainx = np.array([], dtype=np.int64).reshape(0, 3072)
    trainy = np.array([], dtype=np.int64).reshape(0, 160)
    testx = np.array([], dtype=np.int64).reshape(0, 3072)
    testy = np.array([], dtype=np.int64).reshape(0, 160)
    for i in range(1, 161):
        b = np.zeros(160)
        b[i-1]=1
        b = b.reshape(1, 160)
        c = b
        if LeftOrRight == 'Left':
            LoR = 'l'
        elif LeftOrRight == 'Right':
            LoR = 'r'
        dic = 'D:\\image\\' + str(i) + '_' + LoR + '_' + str(1) + '.bmp'
        if path.exists(dic) == False:
            continue
        c = b
        a = convertImagetoArray(dic)
        for j in range(2, numberofseries + 1):
            find_ = dic.find('_')
            dic = dic[:find_] + '_' + LoR + '_' + str(j) + '.bmp'
            if path.exists(dic) == False:
                continue
            x = convertImagetoArray(dic)
            a = np.concatenate((a, x))
            c = np.concatenate((c, b))

        trainx = np.vstack([trainx, a])
        trainy = np.vstack([trainy, c])
        
        test_b = b
        dic = 'D:\\image\\' + str(i) + '_' + LoR + '_' + str(numberofseries+1) + '.bmp'
        if path.exists(dic) == False:
            continue
        test_a = convertImagetoArray(dic)
        trainingSeries = 7 - numberofseries
        for k in range(9-trainingSeries,9):
            find_ = dic.find('_')
            dic = dic[:find_] + '_' + LoR + '_' + str(k) + '.bmp'
            if path.exists(dic) == False:
                continue
            x = convertImagetoArray(dic)
            test_a = np.concatenate((test_a,x))
            test_b = np.concatenate((test_b,b))
        
        testx=np.vstack([testx,test_a])
        testy=np.vstack([testy,test_b])
    
    return trainx,trainy,testx,testy

# %%
trainx, trainy, testx, testy = extractdatabase('Left',7)
# Out:
# D:\image\1_l_1.bmp
# D:\image\1_l_2.bmp
# D:\image\1_l_3.bmp
# D:\image\1_l_4.bmp
# D:\image\1_l_5.bmp
# D:\image\1_l_6.bmp
# D:\image\1_l_7.bmp
# D:\image\1_l_8.bmp
# D:\image\2_l_1.bmp
# D:\image\2_l_2.bmp
# D:\image\2_l_3.bmp
# D:\image\2_l_4.bmp
# D:\image\2_l_5.bmp
# D:\image\2_l_6.bmp
# D:\image\2_l_7.bmp
# D:\image\2_l_8.bmp
# D:\image\3_l_1.bmp
# D:\image\3_l_2.bmp
# D:\image\3_l_3.bmp
# D:\image\3_l_4.bmp
# D:\image\3_l_5.bmp
# D:\image\3_l_6.bmp
# D:\image\3_l_7.bmp
# D:\image\3_l_8.bmp
# D:\image\4_l_1.bmp
# D:\image\4_l_2.bmp
# D:\image\4_l_3.bmp
# D:\image\4_l_4.bmp
# D:\image\4_l_5.bmp
# D:\image\4_l_6.bmp
# D:\image\4_l_7.bmp
# D:\image\4_l_8.bmp
# D:\image\5_l_1.bmp
# D:\image\5_l_2.bmp
# D:\image\5_l_3.bmp
# D:\image\5_l_4.bmp
# D:\image\5_l_5.bmp
# D:\image\5_l_6.bmp
# D:\image\5_l_7.bmp
# D:\image\5_l_8.bmp
# D:\image\6_l_1.bmp
# D:\image\6_l_2.bmp
# D:\image\6_l_3.bmp
# D:\image\6_l_4.bmp
# D:\image\6_l_5.bmp
# D:\image\6_l_6.bmp
# D:\image\6_l_7.bmp
# D:\image\6_l_8.bmp
# D:\image\7_l_1.bmp
# D:\image\7_l_2.bmp
# D:\image\7_l_3.bmp
# D:\image\7_l_4.bmp
# D:\image\7_l_5.bmp
# D:\image\7_l_6.bmp
# D:\image\7_l_7.bmp
# D:\image\7_l_8.bmp
# D:\image\8_l_1.bmp
# D:\image\8_l_2.bmp
# D:\image\8_l_3.bmp
# D:\image\8_l_4.bmp
# D:\image\8_l_5.bmp
# D:\image\8_l_6.bmp
# D:\image\8_l_7.bmp
# D:\image\8_l_8.bmp
# D:\image\9_l_1.bmp
# D:\image\9_l_2.bmp
# D:\image\9_l_3.bmp
# D:\image\9_l_4.bmp
# D:\image\9_l_5.bmp
# D:\image\9_l_6.bmp
# D:\image\9_l_7.bmp
# D:\image\9_l_8.bmp
# D:\image\10_l_1.bmp
# D:\image\10_l_2.bmp
# D:\image\10_l_3.bmp
# D:\image\10_l_4.bmp
# D:\image\10_l_5.bmp
# D:\image\10_l_6.bmp
# D:\image\10_l_7.bmp
# D:\image\10_l_8.bmp
# D:\image\11_l_1.bmp
# D:\image\11_l_2.bmp
# D:\image\11_l_3.bmp
# D:\image\11_l_4.bmp
# D:\image\11_l_5.bmp
# D:\image\11_l_6.bmp
# D:\image\11_l_7.bmp
# D:\image\11_l_8.bmp
# D:\image\12_l_1.bmp
# D:\image\12_l_2.bmp
# D:\image\12_l_3.bmp
# D:\image\12_l_4.bmp
# D:\image\12_l_5.bmp
# D:\image\12_l_6.bmp
# D:\image\12_l_7.bmp
# D:\image\12_l_8.bmp
# D:\image\13_l_1.bmp
# D:\image\13_l_2.bmp
# D:\image\13_l_3.bmp
# D:\image\13_l_4.bmp
# D:\image\13_l_5.bmp
# D:\image\13_l_6.bmp
# D:\image\13_l_7.bmp
# D:\image\13_l_8.bmp
# D:\image\14_l_1.bmp
# D:\image\14_l_2.bmp
# D:\image\14_l_3.bmp
# D:\image\14_l_4.bmp
# D:\image\14_l_5.bmp
# D:\image\14_l_6.bmp
# D:\image\14_l_7.bmp
# D:\image\14_l_8.bmp
# D:\image\15_l_1.bmp
# D:\image\15_l_2.bmp
# D:\image\15_l_3.bmp
# D:\image\15_l_4.bmp
# D:\image\15_l_5.bmp
# D:\image\15_l_6.bmp
# D:\image\15_l_7.bmp
# D:\image\15_l_8.bmp
# D:\image\16_l_1.bmp
# D:\image\16_l_2.bmp
# D:\image\16_l_3.bmp
# D:\image\16_l_4.bmp
# D:\image\16_l_5.bmp
# D:\image\16_l_6.bmp
# D:\image\16_l_7.bmp
# D:\image\16_l_8.bmp
# D:\image\17_l_1.bmp
# D:\image\17_l_2.bmp
# D:\image\17_l_3.bmp
# D:\image\17_l_4.bmp
# D:\image\17_l_5.bmp
# D:\image\17_l_6.bmp
# D:\image\17_l_7.bmp
# D:\image\17_l_8.bmp
# D:\image\18_l_1.bmp
# D:\image\18_l_2.bmp
# D:\image\18_l_3.bmp
# D:\image\18_l_4.bmp
# D:\image\18_l_5.bmp
# D:\image\18_l_6.bmp
# D:\image\18_l_7.bmp
# D:\image\18_l_8.bmp
# D:\image\19_l_1.bmp
# D:\image\19_l_2.bmp
# D:\image\19_l_3.bmp
# D:\image\19_l_4.bmp
# D:\image\19_l_5.bmp
# D:\image\19_l_6.bmp
# D:\image\19_l_7.bmp
# D:\image\19_l_8.bmp
# D:\image\20_l_1.bmp
# D:\image\20_l_2.bmp
# D:\image\20_l_3.bmp
# D:\image\20_l_4.bmp
# D:\image\20_l_5.bmp
# D:\image\20_l_6.bmp
# D:\image\20_l_7.bmp
# D:\image\20_l_8.bmp
# D:\image\21_l_1.bmp
# D:\image\21_l_2.bmp
# D:\image\21_l_3.bmp
# D:\image\21_l_4.bmp
# D:\image\21_l_5.bmp
# D:\image\21_l_6.bmp
# D:\image\21_l_7.bmp
# D:\image\21_l_8.bmp
# D:\image\22_l_1.bmp
# D:\image\22_l_2.bmp
# D:\image\22_l_3.bmp
# D:\image\22_l_4.bmp
# D:\image\22_l_5.bmp
# D:\image\22_l_6.bmp
# D:\image\22_l_7.bmp
# D:\image\22_l_8.bmp
# D:\image\23_l_1.bmp
# D:\image\23_l_2.bmp
# D:\image\23_l_3.bmp
# D:\image\23_l_4.bmp
# D:\image\23_l_5.bmp
# D:\image\23_l_6.bmp
# D:\image\23_l_7.bmp
# D:\image\23_l_8.bmp
# D:\image\24_l_1.bmp
# D:\image\24_l_2.bmp
# D:\image\24_l_3.bmp
# D:\image\24_l_4.bmp
# D:\image\24_l_5.bmp
# D:\image\24_l_6.bmp
# D:\image\24_l_7.bmp
# D:\image\24_l_8.bmp
# D:\image\25_l_1.bmp
# D:\image\25_l_2.bmp
# D:\image\25_l_3.bmp
# D:\image\25_l_4.bmp
# D:\image\25_l_5.bmp
# D:\image\25_l_6.bmp
# D:\image\25_l_7.bmp
# D:\image\25_l_8.bmp
# D:\image\26_l_1.bmp
# D:\image\26_l_2.bmp
# D:\image\26_l_3.bmp
# D:\image\26_l_4.bmp
# D:\image\26_l_5.bmp
# D:\image\26_l_6.bmp
# D:\image\26_l_7.bmp
# D:\image\26_l_8.bmp
# D:\image\27_l_1.bmp
# D:\image\27_l_2.bmp
# D:\image\27_l_3.bmp
# D:\image\27_l_4.bmp
# D:\image\27_l_5.bmp
# D:\image\27_l_6.bmp
# D:\image\27_l_7.bmp
# D:\image\27_l_8.bmp
# D:\image\28_l_1.bmp
# D:\image\28_l_2.bmp
# D:\image\28_l_3.bmp
# D:\image\28_l_4.bmp
# D:\image\28_l_5.bmp
# D:\image\28_l_6.bmp
# D:\image\28_l_7.bmp
# D:\image\28_l_8.bmp
# D:\image\29_l_1.bmp
# D:\image\29_l_2.bmp
# D:\image\29_l_3.bmp
# D:\image\29_l_4.bmp
# D:\image\29_l_5.bmp
# D:\image\29_l_6.bmp
# D:\image\29_l_7.bmp
# D:\image\29_l_8.bmp
# D:\image\30_l_1.bmp
# D:\image\30_l_2.bmp
# D:\image\30_l_3.bmp
# D:\image\30_l_4.bmp
# D:\image\30_l_5.bmp
# D:\image\30_l_6.bmp
# D:\image\30_l_7.bmp
# D:\image\30_l_8.bmp
# D:\image\31_l_1.bmp
# D:\image\31_l_2.bmp
# D:\image\31_l_3.bmp
# D:\image\31_l_4.bmp
# D:\image\31_l_5.bmp
# D:\image\31_l_6.bmp
# D:\image\31_l_7.bmp
# D:\image\31_l_8.bmp
# D:\image\32_l_1.bmp
# D:\image\33_l_1.bmp
# D:\image\33_l_2.bmp
# D:\image\33_l_3.bmp
# D:\image\33_l_4.bmp
# D:\image\33_l_5.bmp
# D:\image\33_l_6.bmp
# D:\image\33_l_7.bmp
# D:\image\33_l_8.bmp
# D:\image\34_l_1.bmp
# D:\image\34_l_2.bmp
# D:\image\34_l_3.bmp
# D:\image\34_l_4.bmp
# D:\image\34_l_5.bmp
# D:\image\34_l_6.bmp
# D:\image\34_l_7.bmp
# D:\image\34_l_8.bmp
# D:\image\35_l_1.bmp
# D:\image\35_l_2.bmp
# D:\image\35_l_3.bmp
# D:\image\35_l_4.bmp
# D:\image\35_l_5.bmp
# D:\image\35_l_6.bmp
# D:\image\35_l_7.bmp
# D:\image\35_l_8.bmp
# D:\image\36_l_1.bmp
# D:\image\36_l_2.bmp
# D:\image\36_l_3.bmp
# D:\image\36_l_4.bmp
# D:\image\36_l_5.bmp
# D:\image\36_l_6.bmp
# D:\image\36_l_7.bmp
# D:\image\36_l_8.bmp
# D:\image\37_l_1.bmp
# D:\image\37_l_2.bmp
# D:\image\37_l_3.bmp
# D:\image\37_l_4.bmp
# D:\image\37_l_5.bmp
# D:\image\37_l_6.bmp
# D:\image\37_l_7.bmp
# D:\image\37_l_8.bmp
# D:\image\38_l_1.bmp
# D:\image\38_l_2.bmp
# D:\image\38_l_3.bmp
# D:\image\38_l_4.bmp
# D:\image\38_l_5.bmp
# D:\image\38_l_6.bmp
# D:\image\38_l_7.bmp
# D:\image\38_l_8.bmp
# D:\image\39_l_1.bmp
# D:\image\39_l_2.bmp
# D:\image\39_l_3.bmp
# D:\image\39_l_4.bmp
# D:\image\39_l_5.bmp
# D:\image\39_l_6.bmp
# D:\image\39_l_7.bmp
# D:\image\39_l_8.bmp
# D:\image\40_l_1.bmp
# D:\image\40_l_2.bmp
# D:\image\40_l_3.bmp
# D:\image\40_l_4.bmp
# D:\image\40_l_5.bmp
# D:\image\40_l_6.bmp
# D:\image\40_l_7.bmp
# D:\image\40_l_8.bmp
# D:\image\41_l_1.bmp
# D:\image\41_l_2.bmp
# D:\image\41_l_3.bmp
# D:\image\41_l_4.bmp
# D:\image\41_l_5.bmp
# D:\image\41_l_6.bmp
# D:\image\41_l_7.bmp
# D:\image\41_l_8.bmp
# D:\image\42_l_1.bmp
# D:\image\42_l_2.bmp
# D:\image\42_l_3.bmp
# D:\image\42_l_4.bmp
# D:\image\42_l_5.bmp
# D:\image\42_l_6.bmp
# D:\image\42_l_7.bmp
# D:\image\42_l_8.bmp
# D:\image\43_l_1.bmp
# D:\image\43_l_2.bmp
# D:\image\43_l_3.bmp
# D:\image\43_l_4.bmp
# D:\image\43_l_5.bmp
# D:\image\43_l_6.bmp
# D:\image\43_l_7.bmp
# D:\image\43_l_8.bmp
# D:\image\44_l_1.bmp
# D:\image\44_l_2.bmp
# D:\image\44_l_3.bmp
# D:\image\44_l_4.bmp
# D:\image\44_l_5.bmp
# D:\image\44_l_6.bmp
# D:\image\44_l_7.bmp
# D:\image\44_l_8.bmp
# D:\image\45_l_1.bmp
# D:\image\45_l_2.bmp
# D:\image\45_l_3.bmp
# D:\image\45_l_4.bmp
# D:\image\45_l_5.bmp
# D:\image\45_l_6.bmp
# D:\image\45_l_7.bmp
# D:\image\45_l_8.bmp
# D:\image\46_l_1.bmp
# D:\image\46_l_2.bmp
# D:\image\46_l_3.bmp
# D:\image\46_l_4.bmp
# D:\image\46_l_5.bmp
# D:\image\46_l_6.bmp
# D:\image\46_l_7.bmp
# D:\image\46_l_8.bmp
# D:\image\47_l_1.bmp
# D:\image\47_l_2.bmp
# D:\image\47_l_3.bmp
# D:\image\47_l_4.bmp
# D:\image\47_l_5.bmp
# D:\image\47_l_6.bmp
# D:\image\47_l_7.bmp
# D:\image\47_l_8.bmp
# D:\image\48_l_1.bmp
# D:\image\48_l_2.bmp
# D:\image\48_l_3.bmp
# D:\image\48_l_4.bmp
# D:\image\48_l_5.bmp
# D:\image\48_l_6.bmp
# D:\image\48_l_7.bmp
# D:\image\48_l_8.bmp
# D:\image\49_l_1.bmp
# D:\image\49_l_2.bmp
# D:\image\49_l_3.bmp
# D:\image\49_l_4.bmp
# D:\image\49_l_5.bmp
# D:\image\49_l_6.bmp
# D:\image\49_l_7.bmp
# D:\image\49_l_8.bmp
# D:\image\50_l_1.bmp
# D:\image\50_l_2.bmp
# D:\image\50_l_3.bmp
# D:\image\50_l_4.bmp
# D:\image\50_l_5.bmp
# D:\image\50_l_6.bmp
# D:\image\50_l_7.bmp
# D:\image\50_l_8.bmp
# D:\image\51_l_1.bmp
# D:\image\51_l_2.bmp
# D:\image\51_l_3.bmp
# D:\image\51_l_4.bmp
# D:\image\51_l_5.bmp
# D:\image\51_l_6.bmp
# D:\image\51_l_7.bmp
# D:\image\51_l_8.bmp
# D:\image\52_l_1.bmp
# D:\image\52_l_2.bmp
# D:\image\52_l_3.bmp
# D:\image\52_l_4.bmp
# D:\image\52_l_5.bmp
# D:\image\52_l_6.bmp
# D:\image\52_l_7.bmp
# D:\image\52_l_8.bmp
# D:\image\53_l_1.bmp
# D:\image\53_l_2.bmp
# D:\image\53_l_3.bmp
# D:\image\53_l_4.bmp
# D:\image\53_l_5.bmp
# D:\image\53_l_6.bmp
# D:\image\53_l_7.bmp
# D:\image\53_l_8.bmp
# D:\image\54_l_1.bmp
# D:\image\54_l_2.bmp
# D:\image\54_l_3.bmp
# D:\image\54_l_4.bmp
# D:\image\54_l_5.bmp
# D:\image\54_l_6.bmp
# D:\image\54_l_7.bmp
# D:\image\54_l_8.bmp
# D:\image\55_l_1.bmp
# D:\image\56_l_1.bmp
# D:\image\56_l_2.bmp
# D:\image\56_l_3.bmp
# D:\image\56_l_4.bmp
# D:\image\56_l_5.bmp
# D:\image\56_l_6.bmp
# D:\image\56_l_7.bmp
# D:\image\56_l_8.bmp
# D:\image\57_l_1.bmp
# D:\image\57_l_2.bmp
# D:\image\57_l_3.bmp
# D:\image\57_l_4.bmp
# D:\image\57_l_5.bmp
# D:\image\57_l_6.bmp
# D:\image\57_l_7.bmp
# D:\image\57_l_8.bmp
# D:\image\58_l_1.bmp
# D:\image\58_l_2.bmp
# D:\image\58_l_3.bmp
# D:\image\58_l_4.bmp
# D:\image\58_l_5.bmp
# D:\image\58_l_6.bmp
# D:\image\58_l_7.bmp
# D:\image\58_l_8.bmp
# D:\image\59_l_1.bmp
# D:\image\59_l_2.bmp
# D:\image\59_l_3.bmp
# D:\image\59_l_4.bmp
# D:\image\59_l_5.bmp
# D:\image\59_l_6.bmp
# D:\image\59_l_7.bmp
# D:\image\59_l_8.bmp
# D:\image\60_l_1.bmp
# D:\image\60_l_2.bmp
# D:\image\60_l_3.bmp
# D:\image\60_l_4.bmp
# D:\image\60_l_5.bmp
# D:\image\60_l_6.bmp
# D:\image\60_l_7.bmp
# D:\image\60_l_8.bmp
# D:\image\61_l_1.bmp
# D:\image\61_l_2.bmp
# D:\image\61_l_3.bmp
# D:\image\61_l_4.bmp
# D:\image\61_l_5.bmp
# D:\image\61_l_6.bmp
# D:\image\61_l_7.bmp
# D:\image\61_l_8.bmp
# D:\image\62_l_1.bmp
# D:\image\62_l_2.bmp
# D:\image\62_l_3.bmp
# D:\image\62_l_4.bmp
# D:\image\62_l_5.bmp
# D:\image\62_l_6.bmp
# D:\image\62_l_7.bmp
# D:\image\62_l_8.bmp
# D:\image\63_l_1.bmp
# D:\image\63_l_2.bmp
# D:\image\63_l_3.bmp
# D:\image\63_l_4.bmp
# D:\image\63_l_5.bmp
# D:\image\63_l_6.bmp
# D:\image\63_l_7.bmp
# D:\image\63_l_8.bmp
# D:\image\64_l_1.bmp
# D:\image\64_l_2.bmp
# D:\image\64_l_3.bmp
# D:\image\64_l_4.bmp
# D:\image\64_l_5.bmp
# D:\image\64_l_6.bmp
# D:\image\64_l_7.bmp
# D:\image\64_l_8.bmp
# D:\image\65_l_1.bmp
# D:\image\65_l_2.bmp
# D:\image\65_l_3.bmp
# D:\image\65_l_4.bmp
# D:\image\65_l_5.bmp
# D:\image\65_l_6.bmp
# D:\image\65_l_7.bmp
# D:\image\65_l_8.bmp
# D:\image\66_l_1.bmp
# D:\image\66_l_2.bmp
# D:\image\66_l_3.bmp
# D:\image\66_l_4.bmp
# D:\image\66_l_5.bmp
# D:\image\66_l_6.bmp
# D:\image\66_l_7.bmp
# D:\image\66_l_8.bmp
# D:\image\67_l_1.bmp
# D:\image\67_l_2.bmp
# D:\image\67_l_3.bmp
# D:\image\67_l_4.bmp
# D:\image\67_l_5.bmp
# D:\image\67_l_6.bmp
# D:\image\67_l_7.bmp
# D:\image\67_l_8.bmp
# D:\image\68_l_1.bmp
# D:\image\68_l_2.bmp
# D:\image\68_l_3.bmp
# D:\image\68_l_4.bmp
# D:\image\68_l_5.bmp
# D:\image\68_l_6.bmp
# D:\image\68_l_7.bmp
# D:\image\68_l_8.bmp
# D:\image\69_l_1.bmp
# D:\image\69_l_2.bmp
# D:\image\69_l_3.bmp
# D:\image\69_l_4.bmp
# D:\image\69_l_5.bmp
# D:\image\69_l_6.bmp
# D:\image\69_l_7.bmp
# D:\image\69_l_8.bmp
# D:\image\70_l_1.bmp
# D:\image\70_l_2.bmp
# D:\image\70_l_3.bmp
# D:\image\70_l_4.bmp
# D:\image\70_l_5.bmp
# D:\image\70_l_6.bmp
# D:\image\70_l_7.bmp
# D:\image\70_l_8.bmp
# D:\image\71_l_1.bmp
# D:\image\72_l_1.bmp
# D:\image\73_l_1.bmp
# D:\image\74_l_1.bmp
# D:\image\75_l_1.bmp
# D:\image\76_l_1.bmp
# D:\image\77_l_1.bmp
# D:\image\78_l_1.bmp
# D:\image\79_l_1.bmp
# D:\image\80_l_1.bmp
# D:\image\81_l_1.bmp
# D:\image\82_l_1.bmp
# D:\image\83_l_1.bmp
# D:\image\84_l_1.bmp
# D:\image\85_l_1.bmp
# D:\image\86_l_1.bmp
# D:\image\87_l_1.bmp
# D:\image\88_l_1.bmp
# D:\image\89_l_1.bmp
# D:\image\90_l_1.bmp
# D:\image\91_l_1.bmp
# D:\image\92_l_1.bmp
# D:\image\93_l_1.bmp
# D:\image\94_l_1.bmp
# D:\image\95_l_1.bmp
# D:\image\96_l_1.bmp
# D:\image\97_l_1.bmp
# D:\image\98_l_1.bmp
# D:\image\99_l_1.bmp
# D:\image\100_l_1.bmp
# D:\image\101_l_1.bmp
# D:\image\102_l_1.bmp
# D:\image\103_l_1.bmp
# D:\image\104_l_1.bmp
# D:\image\105_l_1.bmp
# D:\image\106_l_1.bmp
# D:\image\107_l_1.bmp
# D:\image\108_l_1.bmp
# D:\image\109_l_1.bmp
# D:\image\110_l_1.bmp
# D:\image\111_l_1.bmp
# D:\image\112_l_1.bmp
# D:\image\113_l_1.bmp
# D:\image\114_l_1.bmp
# D:\image\115_l_1.bmp
# D:\image\116_l_1.bmp
# D:\image\117_l_1.bmp
# D:\image\118_l_1.bmp
# D:\image\119_l_1.bmp
# D:\image\120_l_1.bmp
# D:\image\121_l_1.bmp
# D:\image\122_l_1.bmp
# D:\image\123_l_1.bmp
# D:\image\124_l_1.bmp
# D:\image\125_l_1.bmp
# D:\image\126_l_1.bmp
# D:\image\127_l_1.bmp
# D:\image\128_l_1.bmp
# D:\image\129_l_1.bmp
# D:\image\130_l_1.bmp
# D:\image\131_l_1.bmp
# D:\image\132_l_1.bmp
# D:\image\133_l_1.bmp
# D:\image\134_l_1.bmp
# D:\image\135_l_1.bmp
# D:\image\136_l_1.bmp
# D:\image\137_l_1.bmp
# D:\image\138_l_1.bmp
# D:\image\139_l_1.bmp
# D:\image\140_l_1.bmp
# D:\image\141_l_1.bmp
# D:\image\141_l_2.bmp
# D:\image\141_l_3.bmp
# D:\image\141_l_4.bmp
# D:\image\141_l_5.bmp
# D:\image\141_l_6.bmp
# D:\image\141_l_7.bmp
# D:\image\141_l_8.bmp
# D:\image\142_l_1.bmp
# D:\image\143_l_1.bmp
# D:\image\144_l_1.bmp
# D:\image\145_l_1.bmp
# D:\image\146_l_1.bmp
# D:\image\147_l_1.bmp
# D:\image\148_l_1.bmp
# D:\image\149_l_1.bmp
# D:\image\150_l_1.bmp
# D:\image\150_l_2.bmp
# D:\image\150_l_3.bmp
# D:\image\150_l_4.bmp
# D:\image\150_l_5.bmp
# D:\image\150_l_6.bmp
# D:\image\150_l_7.bmp
# D:\image\150_l_8.bmp
# D:\image\151_l_1.bmp
# D:\image\151_l_2.bmp
# D:\image\151_l_3.bmp
# D:\image\151_l_4.bmp
# D:\image\151_l_5.bmp
# D:\image\151_l_6.bmp
# D:\image\151_l_7.bmp
# D:\image\151_l_8.bmp
# D:\image\152_l_1.bmp
# D:\image\152_l_2.bmp
# D:\image\152_l_3.bmp
# D:\image\152_l_4.bmp
# D:\image\152_l_5.bmp
# D:\image\152_l_6.bmp
# D:\image\152_l_7.bmp
# D:\image\152_l_8.bmp
# D:\image\153_l_1.bmp
# D:\image\153_l_2.bmp
# D:\image\153_l_3.bmp
# D:\image\153_l_4.bmp
# D:\image\153_l_5.bmp
# D:\image\153_l_6.bmp
# D:\image\153_l_7.bmp
# D:\image\153_l_8.bmp
# D:\image\154_l_1.bmp
# D:\image\154_l_2.bmp
# D:\image\154_l_3.bmp
# D:\image\154_l_4.bmp
# D:\image\154_l_5.bmp
# D:\image\154_l_6.bmp
# D:\image\154_l_7.bmp
# D:\image\154_l_8.bmp
# D:\image\155_l_1.bmp
# D:\image\155_l_2.bmp
# D:\image\155_l_3.bmp
# D:\image\155_l_4.bmp
# D:\image\155_l_5.bmp
# D:\image\155_l_6.bmp
# D:\image\155_l_7.bmp
# D:\image\155_l_8.bmp
# D:\image\156_l_1.bmp
# D:\image\156_l_2.bmp
# D:\image\156_l_3.bmp
# D:\image\156_l_4.bmp
# D:\image\156_l_5.bmp
# D:\image\156_l_6.bmp
# D:\image\156_l_7.bmp
# D:\image\156_l_8.bmp
# D:\image\157_l_1.bmp
# D:\image\157_l_2.bmp
# D:\image\157_l_3.bmp
# D:\image\157_l_4.bmp
# D:\image\157_l_5.bmp
# D:\image\157_l_6.bmp
# D:\image\157_l_7.bmp
# D:\image\157_l_8.bmp
# D:\image\158_l_1.bmp
# D:\image\158_l_2.bmp
# D:\image\158_l_3.bmp
# D:\image\158_l_4.bmp
# D:\image\158_l_5.bmp
# D:\image\158_l_6.bmp
# D:\image\158_l_7.bmp
# D:\image\158_l_8.bmp
# D:\image\159_l_1.bmp
# D:\image\159_l_2.bmp
# D:\image\159_l_3.bmp
# D:\image\159_l_4.bmp
# D:\image\159_l_5.bmp
# D:\image\159_l_6.bmp
# D:\image\159_l_7.bmp
# D:\image\159_l_8.bmp
# D:\image\160_l_1.bmp
# D:\image\160_l_2.bmp
# D:\image\160_l_3.bmp
# D:\image\160_l_4.bmp
# D:\image\160_l_5.bmp
# D:\image\160_l_6.bmp
# D:\image\160_l_7.bmp
# D:\image\160_l_8.bmp

# %%
print(trainx.shape)
# Out:
# (560, 3072)

# %%
print(trainx[0])
# Out:
# [216 225 218 ... 255 255 255]

# %%
ide=10
# Convolutional Layer 1.
filter_size1=5                  # Convolution filters are 5x5
num_filters1=36                 # We have 16 of these filters

# Convolutional Layer 2.
filter_size2=3                  # Convolution filters are 5x5
num_filters2=36                 # We have 36 of these filters

# Multilayer perceptron
fc_size= 128

# %%
def getnewbatch(iteraction):
    global batch_iterations
    miniX=trainx[(25*batch_iterations):(25+(25*batch_iterations))]
    miniY=BtrainY[(25*batch_iterations):(25+(25*batch_iterations))]
    batch_iterations+=1
    if batch_iterations == 16:
        batch_iterations=0
    return miniX,miniY

# %%
def  plot_images (images, cls_true, cls_pred=None):
#    assert len(images) == len(cls_true) == 9
    # Create figure with 3x3 sub-plots.
    fig, axes = plt.subplots(3, 3)
    fig.subplots_adjust(hspace=0.3, wspace=0.3)

    for i, ax in enumerate(axes.flat):
        # Plot image.
        ax.imshow(images[i].reshape(img_shape), cmap='binary')

        # Show true and predicted classes.
        if cls_pred is None:
            xlabel = "True: {0}".format(cls_true[i])
        else:
            xlabel = "True: {0}, Pred: {1}".format(cls_true[i], cls_pred[i])

        # Show the classes as the label on the x-axis.
        ax.set_xlabel(xlabel)
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
    
    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()

# %%
def plot_example_errors(cls_pred, correct):
    # This function is called from print_test_accuracy() below.

    # cls_pred is an array of the predicted class-number for
    # all images in the test-set.

    # correct is a boolean array whether the predicted class
    # is equal to the true class for each image in the test-set.

    # Negate the boolean array.
    incorrect = (correct == False)
    
    # Get the images from the test-set that have been
    # incorrectly classified.
    images = testx[incorrect]
    
    # Get the predicted classes for those images.
    cls_pred = cls_pred[incorrect]

    # Get the true classes for those images.
    cls_true = testy[incorrect]
    
    # Plot the first 9 images.
    plot_images(images=images[0:9],
                cls_true=cls_true[0:9],
                cls_pred=cls_pred[0:9])

# %%
def optimize(num_iterations):
    # Ensure we update the global variable rather than a local copy.
    global total_iterations
    
    # Start-time used for printing time-usage below.
    start_time = time.time()

    for i in range(total_iterations,
                   total_iterations + num_iterations):

        # Get a batch of training examples.
        # x_batch now holds a batch of images and
        # y_true_batch are the true labels for those images.
        x_batch,y_true_batch= getnewbatch(total_iterations)

        # Put the batch into a dict with the proper names
        # for placeholder variables in the TensorFlow graph.
        feed_dict_train = {x: x_batch,
                           y_true: y_true_batch}

        # Run the optimizer using this batch of training data.
        # TensorFlow assigns the variables in feed_dict_train
        # to the placeholder variables and then runs the optimizer.
        session.run(optimizer, feed_dict=feed_dict_train)


        # Print status every 100 iterations.
        if i % 20 == 0:
            # Calculate the accuracy on the training-set.
            acc = session.run(accuracy, feed_dict=feed_dict_train)

            # Message for printing.
            msg = "Optimization Iteration: {0:>6}, Training Accuracy: {1:>6.1%}"

            # Print it.
            print(msg.format(i + 1, acc))
            print_test_accuracy()
    # Update the total number of iterations performed.
    total_iterations += num_iterations

    # Ending time.
    end_time = time.time()

    # Difference between start and end-times.
    time_dif = end_time - start_time

    # Print the time-usage.
    print("Time usage: " + str(timedelta(seconds=int(round(time_dif)))))

# %%
test_batch_size = 25
def print_test_accuracy(show_example_errors=False):

    # Number of images in the test-set.
    num_test = len(testx)

    # Allocate an array for the predicted classes which
    # will be calculated in batches and filled into this array.
    cls_pred = np.zeros(shape=num_test, dtype=np.int)

    # Now calculate the predicted classes for the batches.
    # We will just iterate through all the batches.
    # There might be a more clever and Pythonic way of doing this.

    # The starting index for the next batch is denoted i.
    i = 0

    while i < num_test:
        # The ending index for the next batch is denoted j.
        j = min(i + test_batch_size, num_test)

        # Get the images from the test-set between index i and j.
        images = testx[i:j, :]

        # Get the associated labels.
        labels = BtrainY[i:j, :]

        # Create a feed-dict with these images and labels.
        feed_dict = {x: images,
                     y_true: labels}

        # Calculate the predicted class using TensorFlow.
        cls_pred[i:j] = session.run(y_pred_cls, feed_dict=feed_dict)

        # Set the start-index for the next batch to the
        # end-index of the current batch.
        i = j
    
    # Convenience variable for the true class-numbers of the test-set.
    cls_true =np.zeros(num_test,np.int8)
    for i in range(0,len(BtestY)):
        cls_true[i] = np.argmax(BtestY[i])
    # Create a boolean array whether each image is correctly classified.
    correct = (cls_true == cls_pred)
#    print(correct)
    # Calculate the number of correctly classified images.
    # When summing a boolean array, False means 0 and True means 1.
    correct_sum = sum(1 for a, b in zip(cls_pred, cls_true) if a == b)
    # Classification accuracy is the number of correctly classified
    # images divided by the total number of images in the test-set.
    acc = float(correct_sum) / num_test

    # Print the accuracy.
    msg = "Accuracy on Test-Set: {0:.1%} ({1} / {2})"
    print(msg.format(acc, correct_sum, num_test))

    # Plot some examples of mis-classifications, if desired.
    if show_example_errors:
        print("Example errors:")
        plot_example_errors(cls_pred=cls_pred, correct=correct)

# %%
def binary(identity,testY,trainY):
    BtestY=np.zeros([len(testY),2])
    BtrainY=np.zeros([len(trainY),2])
    for i in range(0,len(testY)):
        if testY[i,identity]==1:
            BtestY[i,0]=1
        else:
            BtestY[i,1]=1
    for ii in range(0,len(trainY)):
        if trainY[ii,identity]==1:
            BtrainY[ii,0]=1
        else:
            BtrainY[ii,1]=1
    return BtestY, BtrainY
BtestY,BtrainY=binary(9,testy,trainy)

# %%
img_size = 28
img_size_flat = len(testx[0])
img_shape = (48,64)
num_channels = 1
num_classes = 2
images = testx[0:9]
cls_true = np.argwhere(BtestY[0:9])[:,1]
plot_images(images=images, cls_true=cls_true)

# %%
x = tf.placeholder(tf.float32, shape=[None, img_size_flat], name='x')
x_image = tf.reshape(x, [-1, 48, 64, num_channels])
y_true = tf.placeholder(tf.float32, shape=[None, num_classes], name='y_true')
y_true_cls = tf.argmax(y_true, axis=1) 
layer_conv1, weights_conv1 = \
    convolutional.new_conv_layer(input=x_image,
                   num_input_channels=num_channels,
                   filter_size=3,
                   num_filters=32,
                   use_pooling=True)
layer_conv2, weights_conv2 = \
    convolutional.new_conv_layer(input=layer_conv1,
                   num_input_channels=32,
                   filter_size=3,
                   num_filters=32,
                   use_pooling=True)
layer_conv3, weights_conv3 = \
    convolutional.new_conv_layer(input=layer_conv2,
                   num_input_channels=32,
                   filter_size=3,
                   num_filters=64,
                   use_pooling=True)

layer_flat, num_features = convolutional.flatten_layer(layer_conv3)
layer_fc1 = convolutional.new_fc_layer(input=layer_flat,
                         num_inputs=num_features,
                         num_outputs=128,
                         use_relu=True)
layer_fc2 = convolutional.new_fc_layer(input=layer_fc1,
                         num_inputs=128,
                         num_outputs=num_classes,
                         use_relu=False)
y_pred = tf.nn.softmax(layer_fc2)
y_pred_cls = tf.argmax(y_pred, axis=1)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits=layer_fc2,
                                                        labels=y_true)
cost = tf.reduce_mean(cross_entropy)

optimizer  = tf.train.AdamOptimizer(learning_rate=1e-4).minimize(cost)

correct_prediction = tf.equal(y_pred_cls, y_true_cls)
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

session = tf.Session()
session.run(tf.global_variables_initializer())

#   Batch size will be constant to 25

# Counter for total number of iterations performed so far.
total_iterations = 0
batch_iterations = 0

##############################################
optimize(num_iterations=1000)
# Out:
# WARNING:tensorflow:From C:\Users\hungm\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:201: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# Optimization Iteration:      1, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# <ipython-input-13-b00abb4de72c>:9: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   cls_pred = np.zeros(shape=num_test, dtype=np.int)
# Optimization Iteration:     21, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:     41, Training Accuracy: 100.0%
# Accuracy on Test-Set: 97.5% (78 / 80)
# Optimization Iteration:     61, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:     81, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    101, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    121, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    141, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    161, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    181, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    201, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    221, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    241, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    261, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    281, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    301, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    321, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    341, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    361, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    381, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    401, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    421, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    441, Training Accuracy: 100.0%
# Accuracy on Test-Set: 91.2% (73 / 80)
# Optimization Iteration:    461, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    481, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    501, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    521, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    541, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    561, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    581, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    601, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    621, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    641, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    661, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    681, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    701, Training Accuracy: 100.0%
# Accuracy on Test-Set: 97.5% (78 / 80)
# Optimization Iteration:    721, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    741, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    761, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    781, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    801, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    821, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    841, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    861, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    881, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    901, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    921, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    941, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    961, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Optimization Iteration:    981, Training Accuracy: 100.0%
# Accuracy on Test-Set: 98.8% (79 / 80)
# Time usage: 0:00:59
